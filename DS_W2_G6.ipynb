# %% [markdown]
# <a href="https://colab.research.google.com/github/ezequielmartinezbuasso/CURSOWEB/blob/master/DS_W2_G6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Analyze variables, fill in missing values, normalize extreme values.**

# %%
import pandas as pd
import numpy as np
cars_data = pd.read_csv (r'/content/Automotive_2.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
cars_data.head (10)
# Out:
#        dateCrawled                                               name  seller  \
# 0  3/26/2016 14:57  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...  privat
# 1  3/23/2016 20:57                   Renault_clio_mit_nagelneuen_T?!*  privat
# 2  3/19/2016 18:56                              VW_LUPO._1.1l_T?_3/18  privat
# 3  3/30/2016 12:51             Opel_Astra_Caravan_Sport_sehr_gepflegt  privat
# 4  3/26/2016 21:36              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend  privat
# 5  3/15/2016 19:45                   Audi_Q5_3.0_TDI_quattro_S_tronic  privat
# 6   3/7/2016 22:48                                     Alfa_Romeo_147  privat
# 7  3/30/2016 20:57                            renaut_espace_fast_frei  privat
# 8   4/2/2016 10:56                    BMW_e36_316i_Compact_1_9_T?_neu  privat
# 9   4/1/2016 12:53       Renault_Trafic_2.5_dCi_Generation_Expression  privat
#
#   offerType  price   abtest vehicleType yearOfRegistration    gearbox powerPS  \
# ...

# %%
cars_data.isnull().sum()
# Out:
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                    12
# vehicleType            17479
# yearOfRegistration        10
# gearbox                 9350
# powerPS                    4
# model                   9363
# kilometer                  0
# monthOfRegistration       16
# fuelType               15287
# brand                     42
# notRepairedDamage      33167
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                 132
# dtype: int64

# %%
#Jessica---------------------------------
#Como estábamos teniendo problemas al abrir el archivo, lo que hice fue subirlo directamente a la carpeta de trabajo para tenero de rápido acceso
#Sin embargo, como el documento era muy pesado, lo que hice fue convertirlo en zip, subirlo y las siguientes líneas de código son para abrir el archivo zip

#Abrir zip
from io import StringIO
from io import BytesIO
from zipfile import ZipFile
import urllib.request
import pandas as pd 

link = "https://github.com/SteeleP-J/DS-Project/raw/master/Auto.zip"
url = urllib.request.urlopen(link)


with ZipFile(BytesIO(url.read())) as my_zip_file:
    for contained_file in my_zip_file.namelist():
        fzip=my_zip_file.open(contained_file)
        data=fzip.read()

#Convertir el archivo en un data frame con pandas
s=str(data,'utf-8')
data = StringIO(s) 
df=pd.read_csv(data)
df.tail()
# Out:
#             dateCrawled                                          name  seller  \
# 171523  3/14/2016 17:48                    Suche_t4___vito_ab_6_sitze  privat
# 171524   3/5/2016 19:56         Smart_smart_leistungssteigerung_100ps  privat
# 171525  3/19/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 171526  3/20/2016 19:41                        VW_Golf_Kombi_1_9l_TDI  privat
# 171527   3/7/2016 19:39  BMW_M135i_vollausgestattet_NP_52.720____Euro  privat
#
#        offerType  price   abtest vehicleType yearOfRegistration    gearbox  \
# 171523   Angebot   2200     test         NaN               2005        NaN
# 171524   Angebot   1199     test      cabrio               2000  automatik
# 171525   Angebot   9200     test         bus               1996     manual
# 171526   Angebot   3400     test       kombi               2002     manual
# 171527   Angebot  28990  control   limousine               2013     manual
#
# ...

# %%
df['name'] = df['name'].str.replace(r"_"," ")
df['name'] = df['name'].str.replace(r"\W"," ")
df['model'] = df['model'].str.replace(r"\W"," ")
df['name'] = df['name'].str.replace(r"  "," ")
df['name'] = df['name'].str.replace(r"  "," ")
df['name'] = df['name'].str.upper()
df['seller'] = df['seller'].str.title()
df['offerType'] = df['offerType'].str.title()
df['abtest'] = df['abtest'].str.title()
df['vehicleType'] = df['vehicleType'].str.title()
df['gearbox'] = df['gearbox'].str.title()
df['model'] = df['model'].str.title()
df['fuelType'] = df['fuelType'].str.title()
df['brand'] = df['brand'].str.title()
df['notRepairedDamage'] = df['notRepairedDamage'].str.title()
df['dateCrawled'] = pd.to_datetime(df['dateCrawled'],yearfirst=True, errors='coerce')
df['dateCreated'] = pd.to_datetime(df['dateCreated'],yearfirst=True, errors='coerce')
df['lastSeen'] = pd.to_datetime(df['lastSeen'],yearfirst=True, errors='coerce')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#           dateCrawled                                               name  \
# 0 2016-03-26 14:57:00  BMW 320D DPFXENON TEMPOMAT SITZHEIZUNG PDC KLI...
# 1 2016-03-23 20:57:00                     RENAULT CLIO MIT NAGELNEUEN T
# 2 2016-03-19 18:56:00                                VW LUPO 1 1L T 3 18
# 3 2016-03-30 12:51:00             OPEL ASTRA CARAVAN SPORT SEHR GEPFLEGT
# 4 2016-03-26 21:36:00              FORD FOCUS TURNIER 1 6 TDCI DPF TREND
#
#    seller offerType  price   abtest vehicleType yearOfRegistration gearbox  \
# ...
